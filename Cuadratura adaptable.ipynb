# %%
from re import T
from sympy.utilities import lambdify
import sympy as sp
import numpy as np
a = float(input('Límite inferior: '))
b = float(input('Límite superior: '))
N = int(input('Segmentos: '))
x = sp.symbols('x')
f = str(input('Ingrese la función: '))
f = sp.lambdify(x,f)
APP = 0
i = 1
ai = a
hi = (b-a)/2
FAi = f(a)
FCi = f(a+hi)
FBi = f(b)
Si = hi*(FAi + 4*FCi + FBi)/3
Li = 1

if i > 0:
  FD = f(ai + hi/2)
  FE = f(ai + 3*hi/2)
  S1 = hi(FAi + 4*FD + FCi)/6
  S2 = hi*(FCi + 4*FE + FCi)/6
  v1 = ai
  v2 = FAi
  v3 = FCi
  v4 = FBi
  v5 = hi
  v6 = tol
  v7 = Si
  v8 = Li
  i = i - 1
  ai = v1 + v5
  FAi = v5
  FCi = FE
  FBi = v4
  hi = v5/2
  tol = v6/2
  Si = S2
  Li = v8 + 1
  i = i + 1
  ai = v1
  FAi = v2
  FCi = FD
  FBi = v3
  hi =
# Out:
#   File "<ipython-input-1-aa268d1930ce>", line 23
#     S1 = hi(FAi + 4*)
#                     ^
# SyntaxError: invalid syntax
